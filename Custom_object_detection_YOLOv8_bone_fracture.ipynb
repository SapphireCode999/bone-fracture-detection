# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.1/617.1 kB 7.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 194MB/s]

# %%
# trained_model =
# model.train(data="data.yaml", epochs=50, batch=8)

# %%
# trained_model =
model.train(data="/content/drive/MyDrive/Advanced projects/flask app c-vision/object detection yolov8/Bone fracture detection.v1i.yolov8/data.yaml", epochs=50, batch=8)
# Out:
# Ultralytics YOLOv8.0.181 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
